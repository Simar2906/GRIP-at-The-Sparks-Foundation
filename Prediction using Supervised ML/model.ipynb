# %% [markdown]
# ### Task: Predict the Percentage of a student based on the number of study hours

# %% [markdown]
# ## Importing the Libraries

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = pd.read_csv('student_scores - student_scores.csv')
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
X = dataset.iloc[:, 0:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Checking the Dependent and Independent variable

# %%
print(X)
# Out:
# [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]]

# %%
print(y)
# Out:
# [21 47 27 75 30 20 88 60 81 25 85 62 41 42 17 95 30 24 67 69 30 54 35 76
#  86]

# %% [markdown]
# ## Training the Data on Complete Dataset

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting a new result

# %%
print("A student studying for 9.25 hours would be getting " + str(regressor.predict([[9.25]])) + "%")
# Out:
# A student studying for 9.25 hours would be getting [92.90985477]%

# %% [markdown]
# ## Plotting the training

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Decision Tree Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
